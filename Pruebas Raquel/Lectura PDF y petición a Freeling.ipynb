# %%
import nltk
# nltk.download() # para descargar la librería de stopwords en español

# %%
import numpy as np
import pandas as pd
import PyPDF2 
import os
from nltk.corpus import stopwords

# %%
# https://betterprogramming.pub/how-to-convert-pdfs-into-searchable-key-words-with-python-85aab86c544f

# Read files from folder
def readPDF(path):
    files = []
    numPages = []
    texts = []

    for filename in os.listdir(path):
        files.append(filename)

        #open allows you to read the file.
        pdfFileObj = open(path + filename,'rb')
        #The pdfReader variable is a readable object that will be parsed.
        pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

        #Discerning the number of pages will allow us to parse through all the pages.
        num_pages = pdfReader.numPages
        count = 0
        text = ""

        #The while loop will read each page.
        while count < num_pages:
            pageObj = pdfReader.getPage(count)
            count +=1
            text += pageObj.extractText()

        numPages.append(count)

        #This if statement exists to check if the above library returned words. It's done because PyPDF2 cannot read scanned files.
        if text != "":
            text = text
        #If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text.
        else:
            text = textract.process(fileurl, method='tesseract', language='eng')

        texts.append(text)

    consentimientos = {'FileName': files,
                       'NumPages': numPages,
                       'Texto': texts
                      }

    return consentimientos

# %%
consentimientos = readPDF('./Docs/')

# %%
#Mostrar los 50 términos más "centrales" en la colección
import re
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

#Para eliminar los números
def numPreprocessor(tokens):
    r = re.sub('(\d)+', '', tokens.lower())
    return r

#Creación del corpus
corpus = []
for texto in consentimientos['Texto']:
    corpus.append(texto)

#Vectorización
vectorizer = TfidfVectorizer(stop_words=stopwords.words("spanish"), min_df=2, preprocessor=numPreprocessor)
vectors = vectorizer.fit_transform(corpus)

vectors.toarray()

# Para mostrar las 50 palabras más frecuentes
import pandas as pd

sums = vectors.sum(axis=0)

data = []
for col, term in enumerate(vectorizer.get_feature_names()):
    data.append((term, sums[0, col]))

ranking = pd.DataFrame(data, columns=['Palabra','Frecuencia'])
rankingSort = ranking.sort_values('Frecuencia', ascending=False)
rankingSort = rankingSort.head(50)

print(rankingSort.to_string(index=False))
# Out:
#          Palabra  Frecuencia
#          estudio    1.173745
#   consentimiento    0.789769
#           nombre    0.611583
#            firma    0.559065
#      información    0.496565
#        informado    0.486470
#           médico    0.466141
#             hoja    0.429728
#         paciente    0.414937
#            fecha    0.351803
#            datos    0.346841
#          riesgos    0.339713
#     participante    0.309421
#    representante    0.306144
#        explicado    0.305176
#          persona    0.300392
#     investigador    0.273878
#    participación    0.266331
#            salud    0.242242
#         atención    0.215507
#            copia    0.193673
#         presente    0.191707
#        cualquier    0.188731
#            mismo    0.182585
#  características    0.180306
#       beneficios    0.180306
#         objetivo    0.176063
#         posibles    0.175002
#            pueda    0.167907
#          acuerdo    0.166556
#           médica    0.164972
#             edad    0.156265
#        preguntas    0.155850
#             ello    0.154540
#              doy    0.152916
#            puede    0.144107
#            legal    0.142483
#      responsable    0.142483
#       voluntaria    0.136466
#      tratamiento    0.136466
#            todas    0.134090
#         realizar    0.134090
#          testigo    0.127805
#        documento    0.125644
#           sujeto    0.118027
#              ser    0.117372
#          constar    0.115748
#             toda    0.114437
#            tales    0.114437
#             vida    0.114437

# %%
# http://www.corpus.unam.mx/servicio-freeling/
import requests

#Archivo a ser enviado
files = {'file': consentimientos['Texto'][0]}

#Parámetros
params = {'outf': 'tagged', 'format': 'json'}

#Enviar petición
url = "http://www.corpus.unam.mx/servicio-freeling/analyze.php"
r = requests.post(url, files=files, params=params)
#Convertir de formato json
obj = r.json()

# %%
for sentence in obj[:5]:
    for word in sentence:
        print(word)
# Out:
# {'token': 'FPNT', 'lemma': 'fpnt', 'tag': 'NCMS000', 'prob': '0.874985'}
# {'token': '-', 'lemma': '-', 'tag': 'Fg', 'prob': '1'}
# {'token': '07', 'lemma': '7', 'tag': 'Z', 'prob': '1'}
# {'token': 'a', 'lemma': 'a', 'tag': 'SP', 'prob': '0.998775'}
# {'token': '-', 'lemma': '-', 'tag': 'Fg', 'prob': '1'}
# {'token': '31', 'lemma': '31', 'tag': 'Z', 'prob': '1'}
# {'token': '(', 'lemma': '(', 'tag': 'Fpa', 'prob': '1'}
# {'token': 'A', 'lemma': 'a', 'tag': 'SP', 'prob': '0.998775'}
# {'token': ')', 'lemma': ')', 'tag': 'Fpt', 'prob': '1'}
# {'token': 'Protocolo', 'lemma': 'protocolo', 'tag': 'NCMS000', 'prob': '0.980769'}
# {'token': 'XXXXXXXX', 'lemma': 'xxxxxxxx', 'tag': 'AQ0CN00', 'prob': '0.901599'}
# {'token': 'Versión', 'lemma': 'versión', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'X', 'lemma': 'x', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'fecha', 'lemma': 'fecha', 'tag': 'NCFS000', 'prob': '0.990741'}
# {'token': 'XXXXXXXXX', 'lemma': 'xxxxxxxxx', 'tag': 'AQ0CN00', 'prob': '0.901599'}
# {'token': 'Página', 'lemma': 'página', 'tag': 'NCFS000', 'prob': '1'}
# {'token': '1', 'lemma': '1', 'tag': 'Z', 'prob': '1'}
# {'token': 'HOJA', 'lemma': 'hoja', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'DE', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'INFORMACIÓN', 'lemma': 'información', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'A', 'lemma': 'a', 'tag': 'SP', 'prob': '1'}
# {'token': 'EL', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'PACIENTE', 'lemma': 'paciente', 'tag': 'NCCS000', 'prob': '0.5'}
# {'token': 'Y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'CONSENTIMIENTO', 'lemma': 'consentimiento', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'INFORMADO', 'lemma': 'informar', 'tag': 'VMP00SM', 'prob': '1'}
# {'token': 'Código', 'lemma': 'código', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'Protocolo', 'lemma': 'protocolo', 'tag': 'NCMS000', 'prob': '0.980769'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'EUDRACT', 'lemma': 'eudract', 'tag': 'NCMS000', 'prob': '0.746574'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Promotor', 'lemma': 'promotor', 'tag': 'NCMS000', 'prob': '0.983871'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Versión', 'lemma': 'versión', 'tag': 'NCFS000', 'prob': '1'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Fecha', 'lemma': 'fecha', 'tag': 'NCFS000', 'prob': '0.990741'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'la', 'lemma': 'el', 'tag': 'DA0FS0', 'prob': '0.98926'}
# {'token': 'versión', 'lemma': 'versión', 'tag': 'NCFS000', 'prob': '1'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Nombre', 'lemma': 'nombre', 'tag': 'NCMS000', 'prob': '0.995342'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'Inv', 'lemma': 'inv', 'tag': 'AQ0CN00', 'prob': '0.368199'}
# {'token': 'estigador', 'lemma': 'estigador', 'tag': 'NCMS000', 'prob': '0.777778'}
# {'token': 'Principal', 'lemma': 'principal', 'tag': 'AQ0CS00', 'prob': '0.984551'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Datos', 'lemma': 'dato', 'tag': 'NCMP000', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'contacto', 'lemma': 'contacto', 'tag': 'NCMS000', 'prob': '0.994186'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Centro', 'lemma': 'centro', 'tag': 'NCMS000', 'prob': '0.999117'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Servicio', 'lemma': 'servicio', 'tag': 'NCMS000', 'prob': '1'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': 'Título', 'lemma': 'título', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'ensayo', 'lemma': 'ensayo', 'tag': 'NCMS000', 'prob': '0.983871'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': '1', 'lemma': '1', 'tag': 'Z', 'prob': '1'}
# {'token': '.', 'lemma': '.', 'tag': 'Fp', 'prob': '1'}
# {'token': 'INTRODUCCIÓN', 'lemma': 'introducción', 'tag': 'NCFS000', 'prob': '1'}
# {'token': ':', 'lemma': ':', 'tag': 'Fd', 'prob': '1'}
# {'token': '(', 'lemma': '(', 'tag': 'Fpa', 'prob': '1'}
# {'token': 'Texto', 'lemma': 'texto', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'fijo', 'lemma': 'fijo', 'tag': 'AQ0MS00', 'prob': '0.986111'}
# {'token': 'para', 'lemma': 'para', 'tag': 'SP', 'prob': '0.999834'}
# {'token': 'todos', 'lemma': 'todo', 'tag': 'DI0MP0', 'prob': '0.70665'}
# {'token': 'los', 'lemma': 'el', 'tag': 'DA0MP0', 'prob': '0.992728'}
# {'token': 'estudios', 'lemma': 'estudio', 'tag': 'NCMP000', 'prob': '1'}
# {'token': ')', 'lemma': ')', 'tag': 'Fpt', 'prob': '1'}
# {'token': 'Nos', 'lemma': 'nos', 'tag': 'PP1CP00', 'prob': '0.810258'}
# {'token': 'dirigimos', 'lemma': 'dirigir', 'tag': 'VMIS1P0', 'prob': '0.500001'}
# {'token': 'a', 'lemma': 'a', 'tag': 'SP', 'prob': '0.998775'}
# {'token': 'usted', 'lemma': 'usted', 'tag': 'PP2CS0P', 'prob': '1'}
# {'token': 'para', 'lemma': 'para', 'tag': 'SP', 'prob': '0.999834'}
# {'token': 'informar', 'lemma': 'informar', 'tag': 'VMN0000', 'prob': '1'}
# {'token': 'le', 'lemma': 'le', 'tag': 'PP3CSD0', 'prob': '1'}
# {'token': 'sobre', 'lemma': 'sobre', 'tag': 'SP', 'prob': '0.997804'}
# {'token': 'un', 'lemma': 'uno', 'tag': 'DI0MS0', 'prob': '1'}
# {'token': 'ensayo', 'lemma': 'ensayo', 'tag': 'NCMS000', 'prob': '0.983871'}
# {'token': 'clínico', 'lemma': 'clínico', 'tag': 'AQ0MS00', 'prob': '0.661294'}
# {'token': 'en', 'lemma': 'en', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'que', 'lemma': 'que', 'tag': 'PR0CN00', 'prob': '0.550139'}
# {'token': 'se', 'lemma': 'se', 'tag': 'P00CN00', 'prob': '0.494509'}
# {'token': 'le', 'lemma': 'le', 'tag': 'PP3CSD0', 'prob': '1'}
# {'token': 'invita', 'lemma': 'invitar', 'tag': 'VMIP3S0', 'prob': '0.980769'}
# {'token': 'a', 'lemma': 'a', 'tag': 'SP', 'prob': '0.998775'}
# {'token': 'participar', 'lemma': 'participar', 'tag': 'VMN0000', 'prob': '1'}
# {'token': '.', 'lemma': '.', 'tag': 'Fp', 'prob': '1'}
# {'token': 'El', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'estudio', 'lemma': 'estudio', 'tag': 'NCMS000', 'prob': '0.97043'}
# {'token': 'ha', 'lemma': 'haber', 'tag': 'VAIP3S0', 'prob': '0.999889'}
# {'token': 'sido', 'lemma': 'ser', 'tag': 'VSP00SM', 'prob': '1'}
# {'token': 'aprobado', 'lemma': 'aprobar', 'tag': 'VMP00SM', 'prob': '0.958015'}
# {'token': 'por', 'lemma': 'por', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'Comité', 'lemma': 'comité', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'Ético', 'lemma': 'ético', 'tag': 'AQ0MS00', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'Investigación', 'lemma': 'investigación', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'con', 'lemma': 'con', 'tag': 'SP', 'prob': '1'}
# {'token': 'medicamentos', 'lemma': 'medicamento', 'tag': 'NCMP000', 'prob': '1'}
# {'token': 'correspondiente', 'lemma': 'correspondiente', 'tag': 'AQ0CS00', 'prob': '0.993421'}
# {'token': 'y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'la', 'lemma': 'el', 'tag': 'DA0FS0', 'prob': '0.98926'}
# {'token': 'Agencia', 'lemma': 'agencia', 'tag': 'NCFS000', 'prob': '0.980583'}
# {'token': 'Española', 'lemma': 'español', 'tag': 'AQ0FS00', 'prob': '0.9614'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'Medicamento', 'lemma': 'medicamento', 'tag': 'NCMS000', 'prob': '1'}
# {'token': 'y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'Productos', 'lemma': 'producto', 'tag': 'NCMP000', 'prob': '0.998512'}
# {'token': 'Sanitarios', 'lemma': 'sanitario', 'tag': 'AQ0MP00', 'prob': '0.98913'}
# {'token': ',', 'lemma': ',', 'tag': 'Fc', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'acuerdo', 'lemma': 'acuerdo', 'tag': 'NCMS000', 'prob': '0.999311'}
# {'token': 'a', 'lemma': 'a', 'tag': 'SP', 'prob': '0.998775'}
# {'token': 'la', 'lemma': 'el', 'tag': 'DA0FS0', 'prob': '0.98926'}
# {'token': 'le', 'lemma': 'le', 'tag': 'PP3CSD0', 'prob': '1'}
# {'token': 'gislación', 'lemma': 'gislación', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'vigente', 'lemma': 'vigente', 'tag': 'AQ0CS00', 'prob': '1'}
# {'token': ',', 'lemma': ',', 'tag': 'Fc', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'Real', 'lemma': 'real', 'tag': 'AQ0CS00', 'prob': '0.82839'}
# {'token': 'Decreto', 'lemma': 'decreto', 'tag': 'NCMS000', 'prob': '0.994186'}
# {'token': '1090/2015', 'lemma': '1090/2015', 'tag': 'Z', 'prob': '1'}
# {'token': ',', 'lemma': ',', 'tag': 'Fc', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': '4', 'lemma': '4', 'tag': 'Z', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'diciembre', 'lemma': 'diciembre', 'tag': 'NCMS000', 'prob': '1'}
# {'token': ',', 'lemma': ',', 'tag': 'Fc', 'prob': '1'}
# {'token': 'por', 'lemma': 'por', 'tag': 'SP', 'prob': '1'}
# {'token': 'el', 'lemma': 'el', 'tag': 'DA0MS0', 'prob': '1'}
# {'token': 'que', 'lemma': 'que', 'tag': 'PR0CN00', 'prob': '0.550139'}
# {'token': 'se', 'lemma': 'se', 'tag': 'P00CN00', 'prob': '0.494509'}
# {'token': 'regulan', 'lemma': 'regular', 'tag': 'VMIP3P0', 'prob': '1'}
# {'token': 'los', 'lemma': 'el', 'tag': 'DA0MP0', 'prob': '0.992728'}
# {'token': 'ensayos', 'lemma': 'ensayo', 'tag': 'NCMP000', 'prob': '1'}
# {'token': 'clínicos', 'lemma': 'clínico', 'tag': 'AQ0MP00', 'prob': '0.661294'}
# {'token': 'con', 'lemma': 'con', 'tag': 'SP', 'prob': '1'}
# {'token': 'medicamentos', 'lemma': 'medicamento', 'tag': 'NCMP000', 'prob': '1'}
# {'token': '.', 'lemma': '.', 'tag': 'Fp', 'prob': '1'}
# {'token': 'Nuestra', 'lemma': 'nuestro', 'tag': 'DP1FSP', 'prob': '0.867454'}
# {'token': 'intención', 'lemma': 'intención', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'es', 'lemma': 'ser', 'tag': 'VSIP3S0', 'prob': '1'}
# {'token': 'tan', 'lemma': 'tan', 'tag': 'RG', 'prob': '1'}
# {'token': 'sólo', 'lemma': 'sólo', 'tag': 'RG', 'prob': '1'}
# {'token': 'que', 'lemma': 'que', 'tag': 'CS', 'prob': '0.449861'}
# {'token': 'usted', 'lemma': 'usted', 'tag': 'PP2CS0P', 'prob': '1'}
# {'token': 'reciba', 'lemma': 'recibir', 'tag': 'VMSP3S0', 'prob': '0.493976'}
# {'token': 'la', 'lemma': 'el', 'tag': 'DA0FS0', 'prob': '0.98926'}
# {'token': 'información', 'lemma': 'información', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'correcta', 'lemma': 'correcto', 'tag': 'AQ0FS00', 'prob': '1'}
# {'token': 'y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'suficiente', 'lemma': 'suficiente', 'tag': 'AQ0CS00', 'prob': '0.993994'}
# {'token': 'para', 'lemma': 'para', 'tag': 'SP', 'prob': '0.999834'}
# {'token': 'que', 'lemma': 'que', 'tag': 'CS', 'prob': '0.449861'}
# {'token': 'pueda', 'lemma': 'poder', 'tag': 'VMSP3S0', 'prob': '0.499421'}
# {'token': 'evaluar', 'lemma': 'evaluar', 'tag': 'VMN0000', 'prob': '1'}
# {'token': 'y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'juzgar', 'lemma': 'juzgar', 'tag': 'VMN0000', 'prob': '1'}
# {'token': 'si', 'lemma': 'si', 'tag': 'CS', 'prob': '0.999827'}
# {'token': 'quiere', 'lemma': 'querer', 'tag': 'VMIP3S0', 'prob': '0.999058'}
# {'token': 'o', 'lemma': 'o', 'tag': 'CC', 'prob': '0.999864'}
# {'token': 'n', 'lemma': 'n', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'o', 'lemma': 'o', 'tag': 'CC', 'prob': '0.999864'}
# {'token': 'participar', 'lemma': 'participar', 'tag': 'VMN0000', 'prob': '1'}
# {'token': 'en', 'lemma': 'en', 'tag': 'SP', 'prob': '1'}
# {'token': 'este', 'lemma': 'este', 'tag': 'DD0MS0', 'prob': '0.949201'}
# {'token': 'ensayo', 'lemma': 'ensayo', 'tag': 'NCMS000', 'prob': '0.983871'}
# {'token': '.', 'lemma': '.', 'tag': 'Fp', 'prob': '1'}
# {'token': 'Para', 'lemma': 'para', 'tag': 'SP', 'prob': '0.999834'}
# {'token': 'ello', 'lemma': 'ello', 'tag': 'PD00S00', 'prob': '1'}
# {'token': 'lea', 'lemma': 'leer', 'tag': 'VMSP3S0', 'prob': '0.634857'}
# {'token': 'esta', 'lemma': 'este', 'tag': 'DD0FS0', 'prob': '0.978817'}
# {'token': 'hoja', 'lemma': 'hoja', 'tag': 'NCFS000', 'prob': '1'}
# {'token': 'informativa', 'lemma': 'informativo', 'tag': 'AQ0FS00', 'prob': '1'}
# {'token': 'con', 'lemma': 'con', 'tag': 'SP', 'prob': '1'}
# {'token': 'atención', 'lemma': 'atención', 'tag': 'NCFS000', 'prob': '0.997312'}
# {'token': 'y', 'lemma': 'y', 'tag': 'CC', 'prob': '0.999989'}
# {'token': 'nosotros', 'lemma': 'nosotros', 'tag': 'PP1MP00', 'prob': '1'}
# {'token': 'le', 'lemma': 'le', 'tag': 'PP3CSD0', 'prob': '1'}
# {'token': 'aclararemos', 'lemma': 'aclarar', 'tag': 'VMIF1P0', 'prob': '1'}
# {'token': 'las', 'lemma': 'el', 'tag': 'DA0FP0', 'prob': '0.988184'}
# {'token': 'dudas', 'lemma': 'duda', 'tag': 'NCFP000', 'prob': '0.99505'}
# {'token': 'que', 'lemma': 'que', 'tag': 'PR0CN00', 'prob': '0.550139'}
# {'token': 'le', 'lemma': 'le', 'tag': 'PP3CSD0', 'prob': '1'}
# {'token': 'puedan', 'lemma': 'poder', 'tag': 'VMSP3P0', 'prob': '0.997382'}
# {'token': 'surgir', 'lemma': 'surgir', 'tag': 'VMN0000', 'prob': '1'}
# {'token': 'después', 'lemma': 'después', 'tag': 'RG', 'prob': '1'}
# {'token': 'de', 'lemma': 'de', 'tag': 'SP', 'prob': '0.999961'}
# {'token': 'la', 'lemma': 'el', 'tag': 'DA0FS0', 'prob': '0.98926'}
# {'token': 'explicación', 'lemma': 'explicación', 'tag': 'NCFS000', 'prob': '1'}
# {'token': '.', 'lemma': '.', 'tag': 'Fp', 'prob': '1'}

# %%
tags = pd.DataFrame(columns=['token', 'lemma', 'tag', 'prob'])
for sentence in obj:
    for word in sentence:
        tags = tags.append(pd.DataFrame(word, index=[0]), ignore_index=True)
    
tags
# Out:
#                token           lemma      tag      prob
# 0               FPNT            fpnt  NCMS000  0.874985
# 1                  -               -       Fg         1
# 2                 07               7        Z         1
# 3                  a               a       SP  0.998775
# 4                  -               -       Fg         1
# ...              ...             ...      ...       ...
# 2870       documento       documento  NCMS000  0.997159
# 2871              de              de       SP  0.999961
# 2872  consentimiento  consentimiento  NCMS000         1
# 2873       informado        informar  VMP00SM         1
# 2874               .               .       Fp         1
#
# [2875 rows x 4 columns]

# %%
tags.tag.unique()
# Out:
# array(['NCMS000', 'Fg', 'Z', 'SP', 'Fpa', 'Fpt', 'AQ0CN00', 'NCFS000',
#        'DA0MS0', 'NCCS000', 'CC', 'VMP00SM', 'Fd', 'DA0FS0', 'AQ0CS00',
#        'NCMP000', 'Fp', 'AQ0MS00', 'DI0MP0', 'DA0MP0', 'PP1CP00',
#        'VMIS1P0', 'PP2CS0P', 'VMN0000', 'PP3CSD0', 'DI0MS0', 'PR0CN00',
#        'P00CN00', 'VMIP3S0', 'VAIP3S0', 'VSP00SM', 'AQ0FS00', 'AQ0MP00',
#        'Fc', 'VMIP3P0', 'DP1FSP', 'VSIP3S0', 'RG', 'CS', 'VMSP3S0',
#        'DD0MS0', 'PD00S00', 'DD0FS0', 'PP1MP00', 'VMIF1P0', 'DA0FP0',
#        'NCFP000', 'VMSP3P0', 'DP3CSN', 'RN', 'DI0CS0', 'PI0MS00',
#        'VMIC3S0', 'VMP00SF', 'VSN0000', 'AQ0CP00', 'Fh', 'PT00000',
#        'DT0CN0', 'AQ0FP00', 'VMIF3S0', 'VMG0000', 'PT0CP00', 'PP3CN00',
#        'PP3MSA0', 'AO0MS00', 'I', 'VMP00PM', 'Fca', 'VMIS3S0', 'Fs',
#        'VMP00PF', 'Fct', 'VMSI3S0', 'NCMN000', 'VMIC3P0', 'PI0MP00',
#        'VMIF3P0', 'PP3MPA0', 'VMIP1S0', 'DI0FS0', 'DI0FP0', 'VSIC1S0',
#        'VMSI3P0', 'NCCP000', 'VMIP1P0', 'DP3CPN', 'VMM03S0', 'VSIF3P0',
#        'PT0CS00', 'PD0CP00', 'DD0FP0', 'DT0MS0', 'DA00S0', 'PR0CS00',
#        'VSIF3S0', 'PI0FS00', 'NC00000', 'DP1MSP', 'VSSP1S0', 'VASP1S0',
#        'PD0MS00', 'PI0CS00', 'VAIP3P0', 'PP3FP00', 'PP2CSO0', 'PP3MS00',
#        'Fz', 'PP1CSN0', 'VAIP1S0', 'PP1CS00', 'DP1CSS', 'DP1CPS',
#        'VMM02S0', 'NCFN000'], dtype=object)
